# %% [markdown]
# ## Table of contents:
# * [Set env](#set_env)
# * [General information on Reactome biopax file](#general_reactome)
#     * [Query 1: Number of elements for each biopax types](#query1)
# * [Complexes](#complexes)
#     * [Complexes in BioPAX specifications](#complexes_in_biopax)
#     * [Complexes in Reactome](#complex_reactome)
#         * [Summary](#summary)
#         * [Query 2: How many black-box complexes?](#query2)
#         * [Query 3: How many complexes have at least one component? ](#query3)
#         * [Query 4: How many complexes have at least one component that is a complex? ](#query4)
#         * [Query 5: How many complexes have at least one component, none of which is a complex? ](#query5)
#         * [Query 6: How many complexes have at least one component that is a blackbox complex ](#query6)
#         * [Query 7: How many complexes have at least one component that is a complex, and all its components that are complexes are actually black box complexes? ](#query7)
#         * [Query 8: How many complexes have at least one component that is a complex, but not a black-box complex? ](#query8)
#         * [Query 9: How many complexes, that are not black boxes, are a component of at least another complex? ](#query9)
#         * [Query 10: Distribution of the number of direct components by complex ](#query10)
#         * [Query 11: Distribution of the number of complexes a complex is a component of](#query11)
#         * [Query 12:  How many interactions directly involve an invalid complex? ?](#query12)
#         * [Query 13: How many different components are involved in the invalid complexes?](#query13)
#         * [Query 14: How many interactions directly involve a component of an invalid complex?](#query14)
#         * [Query 15: How many interactions involve a complex having a direct component that is a component of an invalid complex?](#query15)
#         * [Query 16: How many interactions directly and indirectly involve these components?](#query16)
#
#     * [Identify the redundant complexes](#identify_redundant)
#         * [Query 17: How many pairs of complexes have different identifiers but the same components with the same stoichiometric coefficients and the same cellular localisation?](#query17)
#         * [How many cliques?](#cliques)
#     * [Fix the invalid complexes](#fix_complexes)

# %% [markdown]
# ### Environment <a class="anchor" id="set_env"></a>

# %%
import importlib
import json
import matplotlib.pyplot as plt
import os
import pandas
import rdflib
import rdflib.namespace
import sparqldataframe
import seaborn as sns
from SPARQLWrapper import SPARQLWrapper, JSON
import sys

import time
import jwt
import pathlib

import uri_utils
import complexComponents

# %%
reactomeVersion = 81
species = 170941
# species = 

endpointURL = "http://localhost:3030/REACTOME_DDISCOIDEUM/query"
rdfFormat = "turtle"

workspace = "."
path_results = workspace+'/results-'+str(reactomeVersion)+'-'+str(species)
if not os.path.exists(path_results) :
  os.makedirs(path_results)

prefixesDict = uri_utils.readPrefixesFromFile("defaultPrefixes-release" + 
                                              str(reactomeVersion) + ".json")

# %%
prefixes = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs:<http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX dcterms: <http://purl.org/dc/terms/>

PREFIX chebi: <http://purl.obolibrary.org/obo/chebi/>
PREFIX chebidb: <http://purl.obolibrary.org/obo/CHEBI_>
PREFIX chebirel: <http://purl.obolibrary.org/obo/CHEBI#>

PREFIX up:<http://purl.uniprot.org/core/>
PREFIX udb: <http://purl.uniprot.org/database/>
PREFIX uniprot: <http://purl.uniprot.org/uniprot/>

PREFIX bp3: <http://www.biopax.org/release/biopax-level3.owl#>
PREFIX reactome: <http://www.reactome.org/biopax/""" + str(reactomeVersion)+"""/"""+str(species)+"""#>
"""

# %% [markdown]
# ### General information on the dataset (Reactome Biopax Homo Sapiens v79) <a class="anchor" id="general_reactome"></a>

# %% [markdown]
# Query 1: Number of elements for each biopax types <a class="anchor" id="query1"></a>

# %%
## Reactome - initial file
## Version xml:base="http://www.reactome.org/biopax/79/48887#"> (2022-02-03)

## Number of elements for each biopax types
query="""
# Number of elements for each biopax types in reactome
SELECT ?type (COUNT(DISTINCT(?element)) AS ?nb_elements)
WHERE {
  # ?element a ?type.
  FILTER(STRSTARTS(STR(?type),str(bp3:)) )
}
GROUP BY ?type
ORDER BY DESC (?nb_elements)
"""
pandas.set_option("max_colwidth", 80)
df = sparqldataframe.query(endpointURL, prefixes+query)
df
# Out:
#                                                                               type  \
# 0                  http://www.biopax.org/release/biopax-level3.owl#UnificationXref
# 1                     http://www.biopax.org/release/biopax-level3.owl#SequenceSite
# 2                          http://www.biopax.org/release/biopax-level3.owl#Protein
# 3                  http://www.biopax.org/release/biopax-level3.owl#PublicationXref
# 4                  http://www.biopax.org/release/biopax-level3.owl#FragmentFeature
# 5                 http://www.biopax.org/release/biopax-level3.owl#SequenceInterval
# 6                    http://www.biopax.org/release/biopax-level3.owl#Stoichiometry
# 7                 http://www.biopax.org/release/biopax-level3.owl#RelationshipXref
# 8                         http://www.biopax.org/release/biopax-level3.owl#Evidence
# 9                      http://www.biopax.org/release/biopax-level3.owl#PathwayStep
# 10                http://www.biopax.org/release/biopax-level3.owl#ProteinReference
# 11                         http://www.biopax.org/release/biopax-level3.owl#Complex
# 12             http://www.biopax.org/release/biopax-level3.owl#BiochemicalReaction
# 13                   http://www.biopax.org/release/biopax-level3.owl#SmallMolecule
# 14                       http://www.biopax.org/release/biopax-level3.owl#Catalysis
# 15             http://www.biopax.org/release/biopax-level3.owl#ModificationFeature
# 16          http://www.biopax.org/release/biopax-level3.owl#SmallMoleculeReference
# 17                         http://www.biopax.org/release/biopax-level3.owl#Pathway
# 18                  http://www.biopax.org/release/biopax-level3.owl#PhysicalEntity
# 19                         http://www.biopax.org/release/biopax-level3.owl#Control
# 20      http://www.biopax.org/release/biopax-level3.owl#CellularLocationVocabulary
# 21  http://www.biopax.org/release/biopax-level3.owl#SequenceModificationVocabulary
# 22      http://www.biopax.org/release/biopax-level3.owl#RelationshipTypeVocabulary
# 23                http://www.biopax.org/release/biopax-level3.owl#TemplateReaction
# 24                       http://www.biopax.org/release/biopax-level3.owl#BioSource
# 25          http://www.biopax.org/release/biopax-level3.owl#EvidenceCodeVocabulary
# 26                      http://www.biopax.org/release/biopax-level3.owl#Provenance
# 27      http://www.biopax.org/release/biopax-level3.owl#TemplateReactionRegulation
#
#    nb_elements
# 0        39509
# 1        17345
# 2         9188
# 3         8911
# 4         8013
# 5         8013
# 6         6143
# 7         3471
# 8         3277
# 9         3250
# 10        2521
# 11        2366
# 12        2294
# 13        2106
# 14        1613
# 15        1429
# 16        1295
# 17         979
# 18         750
# 19         161
# 20          82
# 21          52
# 22           4
# 23           4
# 24           1
# 25           1
# 26           1
# 27           1

# %% [markdown]
# ### Complexes <a class="anchor" id="complexes"></a>
#
# #### Complexes in BioPAX specifications <a class="anchor" id="complexes_in_biopax"></a>
#
# - **Complex** (BioPAX-level3 page 48)
#     - physical product of an interaction
#     - **complexes should not be defined recursively** (a complex should not be a component of another complex)
#     - **exceptions are black box complexes** i.e. complexes in which the component property is empty
#     - the `bp3:component` property
#         - has domain: `bp3:Complex`
#         - has range: `bp3:PhysicalEntity`, which subclasses are:
#             - `bp3:Dna`
#             - `bp3:Rna`
#             - `bp3:Protein`
#             - `bp3:Complex` warning: black box complexes only!
#             - `bp3:SmallMolecule`
# - **Black box complex**
# - **Redundant complexes** are complexes having different identifiers, possibly from different databases but having the same chemical and physical properties
#     - redundant complexes form equivalence classes

# %% [markdown]
# #### Complexes in Reactome <a class="anchor" id="complex_reactome"></a>
# ![](./2022_03_09_Complex_Biopax.png)

# %% [markdown]
# Query 2: How many black-box complexes? <a class="anchor" id="query2"></a>

# %%
## OD
query="""
# Blackbox complexes

SELECT (COUNT(DISTINCT ?complexBB) AS ?nbComplexesBB)
WHERE {
  # ?complexBB rdf:type bp3:Complex .
  FILTER NOT EXISTS {
    # ?complexBB bp3:component ?complexComponent . 
  }
}"""

df = sparqldataframe.query(endpointURL, prefixes+query)
df
# Out:
#   nbComplexesBB
# 0           124

# %% [markdown]
# Query 3: How many complexes have at least one component? <a class="anchor" id="query3"></a>

# %%
## OD
query="""
# Complexes that have at least one component
# i.e. complexes that are not blackbox complexes

SELECT (COUNT(DISTINCT ?complex) AS ?nbComplexes)
WHERE {
  # ?complex rdf:type bp3:Complex .
  # ?complex bp3:component ?complexComponent . 
}"""

df = sparqldataframe.query(endpointURL, prefixes+query)
df
# Out:
#   nbComplexes
# 0        2242

# %% [markdown]
# Query 4: How many complexes have at least one component that is a complex? <a class="anchor" id="query4"></a>

# %%
## OD
query="""
# Complexes that have at least one component that is a complex

SELECT (COUNT(DISTINCT ?complex) AS ?nbComplexes)
WHERE {
  # ?complex rdf:type bp3:Complex .
  # ?complex bp3:component ?complexComponent . 
  # ?complexComponent rdf:type bp3:Complex .
}"""

df = sparqldataframe.query(endpointURL, prefixes+query)
df
# Out:
#   nbComplexes
# 0         821

# %% [markdown]
# Query 5: How many complexes have at least one component, none of which is a complex? <a class="anchor" id="query5"></a>

# %%
## OD
query="""
# Complexes that have at least one component, none of which is a complex

SELECT (COUNT(DISTINCT ?complex) AS ?nbComplexes)
WHERE {
  # ?complex rdf:type bp3:Complex .
  # ?complex bp3:component ?complexComponent . 
  FILTER NOT EXISTS {
    # ?complex bp3:component ?someComplexComponent . 
    # ?someComplexComponent rdf:type bp3:Complex .
  }
}"""

df = sparqldataframe.query(endpointURL, prefixes+query)
df
# Out:
#   nbComplexes
# 0        1421

# %% [markdown]
# Query 6: How many complexes have at least one component that is a blackbox complex  <a class="anchor" id="query6"></a>

# %%
## OD
query="""
# Complexes that have at least one component that is a blackbox complex

SELECT (COUNT(DISTINCT ?complex) AS ?nbComplexes)
WHERE {
  # ?complex rdf:type bp3:Complex .
  # ?complex bp3:component ?complexComponent . 
  # ?complexComponent rdf:type bp3:Complex .
  FILTER NOT EXISTS {
    # ?complexComponent bp3:component ?someComplexComponent . 
  }
}"""

df = sparqldataframe.query(endpointURL, prefixes+query)
df
# Out:
#   nbComplexes
# 0          57

# %% [markdown]
# Query 7: How many complexes have at least one component that is a complex, and all its components that are complexes are actually black box complexes? <a class="anchor" id="query7"></a>

# %%
## OD
query="""
# Complexes that have at least one component that is a complex, 
# and all its components that are complexes are actually black box complexes

SELECT (COUNT(DISTINCT ?complex) AS ?nbComplexes)
WHERE {
  # ?complex rdf:type bp3:Complex .
  # ?complex bp3:component ?complexComponent . 
  # ?complexComponent rdf:type bp3:Complex .
  FILTER NOT EXISTS {
    # ?complex bp3:component ?someComplexComponent . 
    # ?someComplexComponent rdf:type bp3:Complex .
    # ?someComplexComponent bp3:component ?someComplexComponentComponent .
  }
}"""

df = sparqldataframe.query(endpointURL, prefixes+query)
df
# Out:
#   nbComplexes
# 0          29

# %% [markdown]
# Query 8: How many complexes have at least one component that is a complex, but not a black-box complex? <a class="anchor" id="query8"></a>
#
# Number of invalid complexes

# %%
## OD
query="""
# All invalid complexes
# Complexes that have at least one component that is a complex, but not a black box complexes

SELECT (COUNT(DISTINCT ?complex) AS ?nbComplexes)
WHERE {
  # ?complex rdf:type bp3:Complex .
  # ?complex bp3:component ?complexComponent . 
  # ?complexComponent rdf:type bp3:Complex .
  # ?complexComponent bp3:component ?someComplexComponentComponent .
}"""

df = sparqldataframe.query(endpointURL, prefixes+query)
df
# Out:
#   nbComplexes
# 0         792

# %% [markdown]
# Query 9: How many complexes, that are not black-boxes, are a component of at least another complex? <a class="anchor" id="query9"></a>

# %%
## OD
query="""
# Complexes that are not black boxes but are a component of at least another complex

SELECT (COUNT(DISTINCT ?complex) AS ?nbComplexes)
WHERE {
  # ?complex rdf:type bp3:Complex .
  # ?complex bp3:component ?complexComponent . 
  
  # ?superComplex bp3:component ?complex .
  # ?superComplex rdf:type bp3:Complex .
}"""

df = sparqldataframe.query(endpointURL, prefixes+query)
df
# Out:
#   nbComplexes
# 0         791

# %% [markdown]
# Query 10: Distribution of the number of direct components by complex <a class="anchor" id="query10"></a>

# %%
## OD
query="""
# Distribution of the number of direct components by complex

SELECT ?complex (COUNT(DISTINCT ?complexComponent) AS ?nbComponents)
WHERE {
  {
    # ?complex rdf:type bp3:Complex .
    # ?complex bp3:component ?complexComponent . 
  }
  UNION
  {
    # ?complex rdf:type bp3:Complex .
    FILTER NOT EXISTS {
      # ?complex bp3:component ?complexComponent . 
    }
  }
}
GROUP BY ?complex
#ORDER BY DESC(?nbComponents)
"""

df = sparqldataframe.query(endpointURL, prefixes+query)
df["nbComponents"] = pandas.to_numeric(df["nbComponents"])
#df.to_csv("./direct_components.csv")
df["nbComponents"].describe()
# Out:
# count    2366.000000
# mean        2.364328
# std         2.774845
# min         0.000000
# 25%         2.000000
# 50%         2.000000
# 75%         2.000000
# max        50.000000
# Name: nbComponents, dtype: float64

# %%
df['nbComponents'].hist(bins=df['nbComponents'].max()+1, log=True)
plt.suptitle("Distribution of the number of direct components by complex")
# Out:
# Text(0.5, 0.98, 'Distribution of the number of direct components by complex')

# %% [markdown]
# Query 11: Distribution of the number of complexes a complex is a component of<a class="anchor" id="query11"></a>

# %%
## OD
query="""
# Distribution of the number of complexes a complex is a component of

SELECT ?complex (COUNT(DISTINCT ?whole) AS ?nbWholes)
WHERE {
  {
    # ?complex rdf:type bp3:Complex .
    # ?whole bp3:component ?complex . 
  }
  UNION
  {
    # ?complex rdf:type bp3:Complex .
    FILTER NOT EXISTS {
      # ?whole bp3:component ?complex .
    }
  }
}
GROUP BY ?complex
#ORDER BY DESC(?nbComponents)
"""

df = sparqldataframe.query(endpointURL, prefixes+query)
df["nbWholes"] = pandas.to_numeric(df["nbWholes"])
df["nbWholes"].describe()
df["nbWholes"].hist(bins=df['nbWholes'].max()+1, log=True)
plt.suptitle("Distribution of the number of complexes a complex is a component of")
# Out:
# Text(0.5, 0.98, 'Distribution of the number of complexes a complex is a component of')

# %% [markdown]
# Query 12: How many interactions **directly** involve invalid complexes? <a class="anchor" id="query12"></a>

# %%
## CJ
query="""
#5734 invalid complexes, composed of 7119 molecules (proteins, smallmolecules et physicalentites)
SELECT (COUNT(DISTINCT ?interaction) AS ?nbInteractions)
WHERE {
  # ?invalidComplex rdf:type bp3:Complex .
  # ?invalidComplex bp3:component ?invalidComplexComponent . 
  # ?invalidComplexComponent rdf:type bp3:Complex .
  # ?invalidComplexComponent bp3:component ?componentOfInvalidComplexComponent .
  
  # ?rel rdfs:subPropertyOf* bp3:participant . 
  # ?interaction ?rel ?complex .
  
}"""

df = sparqldataframe.query(endpointURL, prefixes+query)
df
# Out:
#   nbInteractions
# 0           4073

# %% [markdown]
# Query 13: How many different components (proteins, small molecules et physical entites) are involved in the invalid complexes? <a class="anchor" id="query13"></a>

# %%
## CJ
query="""
#5734 invalid complexes, composed of 7119 molecules (proteins, smallmolecules et physicalentites)
SELECT (COUNT(DISTINCT ?leafComponent) AS ?nbInvalidComplexesComponents)
WHERE {
  # ?invalidComplex rdf:type bp3:Complex .
  # ?invalidComplex bp3:component ?invalidComplexComponent . 
  # ?invalidComplexComponent rdf:type bp3:Complex .
  # ?invalidComplexComponent bp3:component ?someComplexComponentComponent .
  
  # ?invalidComplex bp3:component+ ?leafComponent .
  
  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:Complex .}
  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:Rna .}
  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:Dna .}
  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:Degradation .}
  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:BiochemicalReaction .}
  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:TemplateReaction .}
  
}
"""

df = sparqldataframe.query(endpointURL, prefixes+query)
df
# Out:
#   nbInvalidComplexesComponents
# 0                         1745

# %% [markdown]
# The 5,734 invalid complexes are (in)directly composed of 7,119 distinct entities that are not complexes, interactions, DNA or RNA. Nb: this excludes black-box complexes.

# %% [markdown]
# Query 14: How many interactions **directly** involve these components? <a class="anchor" id="query14"></a>

# %%
## CJ OD
query="""
#5734 invalid complexes, composed of 7119 molecules (proteins, smallmolecules et physicalentites)
#All interactions that have a participant that is a component of an invalid complex 

SELECT (COUNT(DISTINCT ?interact) AS ?nbInteractions)
WHERE {
  # ?invalidComplex rdf:type bp3:Complex .
  # ?invalidComplex bp3:component ?invalidComplexComponent .
  # ?invalidComplexComponent bp3:component ?componentOfInvalidComplexComponent .
  
  # ?invalidComplex bp3:component* ?leafComponent .

  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:Complex .}
  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:Rna .}
  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:Dna .}
  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:Degradation .}
  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:BiochemicalReaction .}
  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:TemplateReaction .} 
  
  # ?interact ?hasParticipant ?leafComponent .
  # ?hasParticipant rdfs:subPropertyOf* bp3:participant .
}"""

df = sparqldataframe.query(endpointURL, prefixes+query)
df
# Out:
#   nbInteractions
# 0            965

# %% [markdown]
# Query 15: How many interactions involve a complex having a **direct** component that is a component of an invalid complex?  <a class="anchor" id="query15"></a>
#
# Interactions involving a complex composed directly of a component of an invalid complex

# %%
query="""
# All interactions that have a participant that is a complex having a direct component that is a component of an invalid complex (excludes black-box complexes)

SELECT (COUNT(DISTINCT ?interact) AS ?nbInteractions)
WHERE {
  # ?invalidComplex rdf:type bp3:Complex .
  # ?invalidComplex bp3:component ?invalidComplexComponent .
  # ?invalidComplexComponent bp3:component ?componentOfInvalidComplexComponent .
  
  # ?invalidComplex bp3:component* ?leafComponent .

  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:Complex .}
  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:Rna .}
  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:Dna .}
  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:Degradation .}
  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:BiochemicalReaction .}
  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:TemplateReaction .}
  
  # ?interactParticipant bp3:component? ?leafComponent . # 0 or 1 path
  # ?interact ?hasParticipant ?interactParticipant .
  # ?hasParticipant rdfs:subPropertyOf* bp3:participant .
}
"""

df = sparqldataframe.query(endpointURL, prefixes+query)
df
# Out:
#   nbInteractions
# 0           1570

# %% [markdown]
# Query 16: How many interactions **directly** and **indirectly** involve these components? <a class="anchor" id="query16"></a>
#
# Interactions involving a complex (valid or invalid) composed indirectly of a component of an invalid complex or the component itself

# %%
## CJ OD
query="""
#5734 invalid complexes, composed of 7119 molecules (proteins, smallmolecules et physicalentites)
#Interactions involving a complex composed indirectly of a component of an invalid complex

SELECT (COUNT(DISTINCT ?interact) AS ?nbInteractions)
WHERE {
  # ?invalidComplex rdf:type bp3:Complex .
  # ?invalidComplex bp3:component ?invalidComplexComponent .
  # ?invalidComplexComponent bp3:component ?componentOfInvalidComplexComponent .
  
  # ?invalidComplex bp3:component* ?leafComponent .
  
  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:Complex .}
  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:Rna .}
  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:Dna .}
  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:Degradation .}
  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:BiochemicalReaction .}
  FILTER NOT EXISTS {  ?leafComponent rdf:type bp3:TemplateReaction .}
  
  
  # ?interactParticipant bp3:component* ?leafComponent . # 0 or more paths
  # ?hasParticipant rdfs:subPropertyOf* bp3:participant .  
  # ?interact ?hasParticipant ?interactParticipant .
}
"""

df = sparqldataframe.query(endpointURL, prefixes+query)
df
# Out:
#   nbInteractions
# 0           1700

# %% [markdown]
# ### Identify the redundant complexes <a class="anchor" id="identify_redundant"></a>

# %% [markdown]
# Query 17: How many pairs of complexes have different identifiers but the same components with the same stoichiometric coefficients and the same cellular location? <a class="anchor" id="query17"></a>

# %%
## OD CJ
query = """
# Retrieve redundant complexes i.e. pairs of complexes having different identifiers but the same components with the same stoichiometric coefficients
SELECT DISTINCT ?complex1  ?complex2 ?loc1# ?id1 ?id2 #?comp ?stoichioValue1 ?stoichioValue2

WHERE {
  #VALUES ?complex { reactome:Complex3 reactome:Complex7 reactome:Complex4 reactome:Complex5 reactome:Complex6 reactome:Complex8 reactome:Complex101 reactome:Complex102 }
  #VALUES ?complex { reactome:Complex102 }
  
  # ?complex1 rdf:type bp3:Complex .
  # ?complex1 and ?complex2 have at least 1 common component (to avoid matching all the pairs of blackbox complexes that do not have any components)
  # ?complex1 bp3:component ?commonComp .
  # ?complex2 bp3:component ?commonComp .
  # ?complex2 rdf:type bp3:Complex .
  # ?complex1 bp3:cellularLocation ?loc1 .
  # ?complex2 bp3:cellularLocation ?loc1 .
  FILTER (str(?complex1) < str(?complex2))
  # ?complex1 and ?complex2 do not have any common component that has different stoichiometric coefficients between the two complexes
  FILTER NOT EXISTS {
    # ?complex1 bp3:component ?comp .
    # ?complex2 bp3:component ?comp .
    #?complex1 bp3:cellularLocation ?loc1 .
    # ?complex1 bp3:componentStoichiometry ?stoichio1 .
    # ?stoichio1 bp3:physicalEntity ?comp .
    # ?stoichio1 bp3:stoichiometricCoefficient ?stoichioValue1 .

    # ?complex2 bp3:componentStoichiometry ?stoichio2 .
    # ?stoichio2 bp3:physicalEntity ?comp .
    #?complex2 bp3:cellularLocation ?loc2 .
    # ?stoichio2 bp3:stoichiometricCoefficient ?stoichioValue2 .
    FILTER (?stoichioValue1 != ?stoichioValue2)
    #FILTER (?loc1 != ?loc2)
  }


  # all the direct components of ?complex1 are also components of ?complex2
  FILTER NOT EXISTS {
    # ?complex1 bp3:component ?comp1 .
    FILTER NOT EXISTS {
      # ?complex2 bp3:component ?comp1 .
    }
  }
  # all the direct components of ?complex2 are also components of ?complex1
  FILTER NOT EXISTS {
    # ?complex2 bp3:component ?comp2 .
    FILTER NOT EXISTS {
      # ?complex1 bp3:component ?comp2 .
    }
  }
 OPTIONAL{ ?complex1 bp3:xref ?xref1 .
    # ?xref1 bp3:db "ComplexPortal" .
    # ?xref1 bp3:id ?id1 . }
  
OPTIONAL{ ?complex2 bp3:xref ?xref2 .
    # ?xref2 bp3:db "ComplexPortal" .
    # ?xref2 bp3:id ?id2 . }
}
"""
df = sparqldataframe.query(endpointURL, prefixes+query)
df
# Out:
# Empty DataFrame
# Columns: [complex1, complex2, loc1]
# Index: []

# %% [markdown]
# How many cliques? <a class="anchor" id="cliques"></a>

# %%
cliques = {df["complex1"][0] : [df["complex2"][0]]}
for row in df.itertuples(index=False):
    if row[0] in cliques :
        cliques[row[0]].append(row[1])
    elif row[1] in cliques :
        cliques[row[1]].append(row[0])
    else :
        found = False
        for i in cliques :
            if row[0] in cliques[i]:
                cliques[i].append(row[1])
                found = True
                break
            elif row[1] in cliques[i]:
                cliques[i].append(row[0])
                found = True
                break
        if not found :
            cliques[row[0]] = list()
            cliques[row[0]].append(row[1])
       
len(cliques)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-66e45bdc79a5> in <module>
# ----> 1 cliques = {df["complex1"][0] : [df["complex2"][0]]}
#       2 for row in df.itertuples(index=False):
#       3     if row[0] in cliques :
#       4         cliques[row[0]].append(row[1])
#       5     elif row[1] in cliques :
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     848
#     849         if is_integer(key) and self.index._should_fallback_to_positional():
# --> 850             return self._values[key]
#     851
#     852         elif key_is_scalar:
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# * * *
# ### Fix the invalid complexes <a class="anchor" id="fix_complexes"></a>
#
# - step 0: retrieve Reactome
#        wget https://reactome.org/download/current/biopax.zip
#        unzip biopax.zip Homo_sapiens.owl
#        echo "Reactome version: $(expr "$(grep xml:base Homo_sapiens.owl)" : '.*http:\/\/www.reactome.org\/biopax\/\([[:digit:]]*\).*')"
#
# - step 1: setup SPARQL endpoint with reactome
#        # broken with fuseki-4.4.0:
#        # temporary fix
#        ${FUSEKI_HOME}/fuseki-server --mem --update /reactome
#        # then manually load Homo_sapiens.owl
#
# - step 2: export the valid complexes
#
# - step 3: export the fixed invalid complexes
#
# - step 4: export reactome without complexes
#
# - step 5: merge

# %% [markdown]
# ![]("./Figure_drawio/2022_03_17_Stoichio.pdf")

# %% [markdown]
# Function 1: fix invalid complexes <a class="anchor" id="function1"></a>

# %%
def fixInvalidComplexes():
    ##### FIX INVALID COMPLEXES
    queryPath = 'queries/template-fixInvalidComplexes.rq'
    sparqlQuery = pathlib.Path(queryPath).read_text().replace('$supplementaryPrefixes$',uri_utils.convertPrefixesDictToSPARQL(prefixesDict)) 
#     sparql = SPARQLWrapper(endpointURL)
    sparql.setQuery(sparqlQuery)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    nbInvalidComplexes = len(results["results"]["bindings"])
    i = 0
    for result in results["results"]["bindings"]:
        print("{}\t{}\t{}".format(i, time.time()-startTime, result['invalidComplex']['value']))
        validGraph = rdflib.Graph()
        validGraph.bind("bp3","http://www.biopax.org/release/biopax-level3.owl#")
        complexComponents.getRepresentationBiopaxValid(endpointURL, result['invalidComplex']['value'], prefixesDict=prefixesDict, targetGraph=validGraph, rdfFormat="turtle", biopaxFilePath="")
        with open(path_results + "/reactome-v" + str(reactomeVersion) + '-' + str(species) + "-" + result['invalidComplex']['value'].replace("http://www.reactome.org/biopax/" + str(reactomeVersion) + "/" + str(species) + "#", "") + "-valid.ttl", 'w',encoding="utf-8") as rdfFile:
            rdfFile.write(validGraph.serialize(format=rdfFormat))#.decode('UTF-8'))
        i += 1
    
     #${JENA_HOME}/bin/riot --time --output=Turtle result/reactome-v81-Complex*.ttl > reactome-v81-complexes-invalid-fixed.ttl

# %% [markdown]
# Function 2: export valid complexes <a class="anchor" id="function2"></a>

# %%
def exportValidComplexes():
    ##### EXPORT VALID PART OF REACTOME
    queryPath = 'queries/template-extractValidComplexes-construct.rq'
    sparqlQuery = pathlib.Path(queryPath).read_text().replace('$supplementaryPrefixes$',uri_utils.convertPrefixesDictToSPARQL(prefixesDict)) 
    sparql.setQuery(sparqlQuery)
    sparql.setReturnFormat(rdfFormat)
    results = sparql.query().convert()
    validGraph = rdflib.Graph()
    validGraph.parse(data=results, format=rdfFormat)

    with open(path_results + "/reactome-v" + str(reactomeVersion) + '-' + str(species) + "-complexes-valid.ttl", 'w', encoding="utf-8") as rdfFile:
        rdfFile.write(validGraph.serialize(format=rdfFormat).encode().decode('UTF-8'))

# %% [markdown]
# Function 3: delete all complexes  <a class="anchor" id="function3"></a>

# %%
def deleteAllComplexes():
    queryPath = 'queries/deleteOriginalComplexes.rq'
    sparqlQuery = pathlib.Path(queryPath).read_text().replace('$supplementaryPrefixes$',uri_utils.convertPrefixesDictToSPARQL(prefixesDict))
    print("Calling: " + endpointURL.replace("query", "update"))
    sparql = SPARQLWrapper(endpointURL.replace("query", "update"))
    sparql.setQuery(sparqlQuery)
    sparql.method = 'POST'
    #sparql.setReturnFormat(JSON)
    sparql.query()

# %%
validGraph = rdflib.Graph()
sparql = SPARQLWrapper(endpointURL)

# %%
startTime = time.time()
fixInvalidComplexes()
endTime = time.time()
print("Duration: {}".format(endTime - startTime))
# Out:
# 0	0.0570063591003418	http://www.reactome.org/biopax/81/170941#Complex15
# 1	0.2719259262084961	http://www.reactome.org/biopax/81/170941#Complex19
# 2	0.3781883716583252	http://www.reactome.org/biopax/81/170941#Complex20
# 3	0.44457411766052246	http://www.reactome.org/biopax/81/170941#Complex22
# 4	0.5636196136474609	http://www.reactome.org/biopax/81/170941#Complex26
# 5	0.6503283977508545	http://www.reactome.org/biopax/81/170941#Complex28
# 6	0.9160797595977783	http://www.reactome.org/biopax/81/170941#Complex32
# 7	1.1327097415924072	http://www.reactome.org/biopax/81/170941#Complex29
# 8	1.3110218048095703	http://www.reactome.org/biopax/81/170941#Complex34
# 9	1.5230841636657715	http://www.reactome.org/biopax/81/170941#Complex35
# 10	1.7519898414611816	http://www.reactome.org/biopax/81/170941#Complex38
# 11	1.9753224849700928	http://www.reactome.org/biopax/81/170941#Complex36
# 12	2.121694803237915	http://www.reactome.org/biopax/81/170941#Complex37
# 13	2.2022085189819336	http://www.reactome.org/biopax/81/170941#Complex39
# 14	2.411858081817627	http://www.reactome.org/biopax/81/170941#Complex41
# 15	3.179983377456665	http://www.reactome.org/biopax/81/170941#Complex43
# 16	4.071102857589722	http://www.reactome.org/biopax/81/170941#Complex44
# 17	4.890833139419556	http://www.reactome.org/biopax/81/170941#Complex45
# 18	5.577911615371704	http://www.reactome.org/biopax/81/170941#Complex46
# 19	6.368754625320435	http://www.reactome.org/biopax/81/170941#Complex48
# 20	7.224908113479614	http://www.reactome.org/biopax/81/170941#Complex59
# 21	7.432460069656372	http://www.reactome.org/biopax/81/170941#Complex60
# 22	7.535588026046753	http://www.reactome.org/biopax/81/170941#Complex62
# 23	7.737309694290161	http://www.reactome.org/biopax/81/170941#Complex64
# 24	7.8539137840271	http://www.reactome.org/biopax/81/170941#Complex67
# 25	8.001775026321411	http://www.reactome.org/biopax/81/170941#Complex70
# 26	8.141023397445679	http://www.reactome.org/biopax/81/170941#Complex73
# 27	8.271976232528687	http://www.reactome.org/biopax/81/170941#Complex75
# 28	8.44896411895752	http://www.reactome.org/biopax/81/170941#Complex76
# 29	8.602636337280273	http://www.reactome.org/biopax/81/170941#Complex78
# 30	8.849342346191406	http://www.reactome.org/biopax/81/170941#Complex82
# 31	8.948434591293335	http://www.reactome.org/biopax/81/170941#Complex84
# 32	9.094433069229126	http://www.reactome.org/biopax/81/170941#Complex85
# 33	9.228607416152954	http://www.reactome.org/biopax/81/170941#Complex86
# 34	9.328641653060913	http://www.reactome.org/biopax/81/170941#Complex88
# 35	9.433201789855957	http://www.reactome.org/biopax/81/170941#Complex90
# 36	9.531604051589966	http://www.reactome.org/biopax/81/170941#Complex92
# 37	9.636209726333618	http://www.reactome.org/biopax/81/170941#Complex95
# 38	9.743579387664795	http://www.reactome.org/biopax/81/170941#Complex97
# 39	9.824907064437866	http://www.reactome.org/biopax/81/170941#Complex99
# 40	9.928427696228027	http://www.reactome.org/biopax/81/170941#Complex101
# 41	10.007811069488525	http://www.reactome.org/biopax/81/170941#Complex106
# 42	10.461466073989868	http://www.reactome.org/biopax/81/170941#Complex112
# 43	10.866573810577393	http://www.reactome.org/biopax/81/170941#Complex107
# 44	11.053109645843506	http://www.reactome.org/biopax/81/170941#Complex109
# 45	11.33056640625	http://www.reactome.org/biopax/81/170941#Complex114
# 46	12.270669221878052	http://www.reactome.org/biopax/81/170941#Complex131
# 47	13.067476987838745	http://www.reactome.org/biopax/81/170941#Complex115
# 48	13.743070840835571	http://www.reactome.org/biopax/81/170941#Complex116
# 49	14.178844451904297	http://www.reactome.org/biopax/81/170941#Complex117
# 50	14.3158597946167	http://www.reactome.org/biopax/81/170941#Complex119
# 51	14.585877418518066	http://www.reactome.org/biopax/81/170941#Complex137
# 52	15.47026252746582	http://www.reactome.org/biopax/81/170941#Complex139
# 53	16.337960720062256	http://www.reactome.org/biopax/81/170941#Complex140
# 54	17.120993614196777	http://www.reactome.org/biopax/81/170941#Complex146
# 55	18.055303812026978	http://www.reactome.org/biopax/81/170941#Complex148
# 56	19.084146976470947	http://www.reactome.org/biopax/81/170941#Complex149
# 57	20.16687512397766	http://www.reactome.org/biopax/81/170941#Complex150
# 58	20.66645073890686	http://www.reactome.org/biopax/81/170941#Complex151
# 59	20.843926668167114	http://www.reactome.org/biopax/81/170941#Complex153
# 60	21.081378936767578	http://www.reactome.org/biopax/81/170941#Complex154
# 61	21.544138193130493	http://www.reactome.org/biopax/81/170941#Complex155
# 62	21.734755516052246	http://www.reactome.org/biopax/81/170941#Complex167
# 63	21.827759981155396	http://www.reactome.org/biopax/81/170941#Complex170
# 64	21.919612169265747	http://www.reactome.org/biopax/81/170941#Complex173
# 65	22.011035919189453	http://www.reactome.org/biopax/81/170941#Complex175
# 66	22.142042636871338	http://www.reactome.org/biopax/81/170941#Complex178
# 67	22.31821370124817	http://www.reactome.org/biopax/81/170941#Complex179
# 68	22.52088475227356	http://www.reactome.org/biopax/81/170941#Complex181
# 69	22.74823808670044	http://www.reactome.org/biopax/81/170941#Complex185
# 70	22.836214542388916	http://www.reactome.org/biopax/81/170941#Complex186
# 71	22.96090292930603	http://www.reactome.org/biopax/81/170941#Complex188
# 72	23.178257942199707	http://www.reactome.org/biopax/81/170941#Complex189
# 73	23.34113645553589	http://www.reactome.org/biopax/81/170941#Complex190
# 74	23.561280727386475	http://www.reactome.org/biopax/81/170941#Complex192
# 75	23.84372067451477	http://www.reactome.org/biopax/81/170941#Complex195
# 76	23.966927766799927	http://www.reactome.org/biopax/81/170941#Complex196
# 77	24.190914392471313	http://www.reactome.org/biopax/81/170941#Complex197
# 78	25.049293518066406	http://www.reactome.org/biopax/81/170941#Complex205
# 79	25.899476528167725	http://www.reactome.org/biopax/81/170941#Complex200
# 80	26.484230279922485	http://www.reactome.org/biopax/81/170941#Complex201
# 81	27.10176110267639	http://www.reactome.org/biopax/81/170941#Complex202
# 82	27.38569736480713	http://www.reactome.org/biopax/81/170941#Complex203
# 83	27.619750261306763	http://www.reactome.org/biopax/81/170941#Complex206
# 84	27.770606517791748	http://www.reactome.org/biopax/81/170941#Complex208
# 85	27.89653253555298	http://www.reactome.org/biopax/81/170941#Complex210
# 86	28.20469856262207	http://www.reactome.org/biopax/81/170941#Complex211
# 87	28.390663385391235	http://www.reactome.org/biopax/81/170941#Complex212
# 88	28.617175340652466	http://www.reactome.org/biopax/81/170941#Complex213
# 89	29.154540061950684	http://www.reactome.org/biopax/81/170941#Complex215
# 90	29.74189853668213	http://www.reactome.org/biopax/81/170941#Complex214
# 91	30.04579997062683	http://www.reactome.org/biopax/81/170941#Complex219
# 92	30.67370104789734	http://www.reactome.org/biopax/81/170941#Complex223
# 93	31.09447932243347	http://www.reactome.org/biopax/81/170941#Complex225
# 94	31.53679370880127	http://www.reactome.org/biopax/81/170941#Complex226
# 95	31.805209159851074	http://www.reactome.org/biopax/81/170941#Complex228
# 96	32.213053703308105	http://www.reactome.org/biopax/81/170941#Complex229
# 97	32.65501403808594	http://www.reactome.org/biopax/81/170941#Complex230
# 98	33.15900945663452	http://www.reactome.org/biopax/81/170941#Complex231
# 99	33.662972927093506	http://www.reactome.org/biopax/81/170941#Complex232
# 100	34.10296034812927	http://www.reactome.org/biopax/81/170941#Complex247
# 101	34.21283507347107	http://www.reactome.org/biopax/81/170941#Complex249
# 102	34.28189253807068	http://www.reactome.org/biopax/81/170941#Complex267
# 103	34.70802617073059	http://www.reactome.org/biopax/81/170941#Complex270
# 104	35.27051329612732	http://www.reactome.org/biopax/81/170941#Complex268
# 105	35.42151403427124	http://www.reactome.org/biopax/81/170941#Complex274
# 106	35.56058740615845	http://www.reactome.org/biopax/81/170941#Complex278
# 107	35.634588956832886	http://www.reactome.org/biopax/81/170941#Complex280
# 108	35.71862268447876	http://www.reactome.org/biopax/81/170941#Complex282
# 109	35.803587436676025	http://www.reactome.org/biopax/81/170941#Complex292
# 110	36.05158758163452	http://www.reactome.org/biopax/81/170941#Complex297
# 111	36.29360270500183	http://www.reactome.org/biopax/81/170941#Complex293
# 112	36.485798835754395	http://www.reactome.org/biopax/81/170941#Complex299
# 113	36.65745711326599	http://www.reactome.org/biopax/81/170941#Complex302
# 114	36.89013910293579	http://www.reactome.org/biopax/81/170941#Complex304
# 115	37.1194965839386	http://www.reactome.org/biopax/81/170941#Complex322
# 116	37.53941011428833	http://www.reactome.org/biopax/81/170941#Complex326
# 117	38.13900017738342	http://www.reactome.org/biopax/81/170941#Complex323
# 118	38.49879240989685	http://www.reactome.org/biopax/81/170941#Complex324
# 119	38.72766137123108	http://www.reactome.org/biopax/81/170941#Complex325
# 120	38.93170619010925	http://www.reactome.org/biopax/81/170941#Complex327
# 121	39.532639503479004	http://www.reactome.org/biopax/81/170941#Complex329
# 122	40.14508128166199	http://www.reactome.org/biopax/81/170941#Complex330
# 123	40.584524631500244	http://www.reactome.org/biopax/81/170941#Complex331
# 124	40.92037630081177	http://www.reactome.org/biopax/81/170941#Complex333
# 125	41.0293755531311	http://www.reactome.org/biopax/81/170941#Complex335
# 126	41.45306181907654	http://www.reactome.org/biopax/81/170941#Complex337
# 127	41.68252968788147	http://www.reactome.org/biopax/81/170941#Complex338
# 128	41.9365553855896	http://www.reactome.org/biopax/81/170941#Complex340
# 129	42.20313477516174	http://www.reactome.org/biopax/81/170941#Complex342
# 130	42.44383120536804	http://www.reactome.org/biopax/81/170941#Complex344
# 131	42.689719676971436	http://www.reactome.org/biopax/81/170941#Complex352
# 132	42.75260257720947	http://www.reactome.org/biopax/81/170941#Complex353
# 133	42.84516644477844	http://www.reactome.org/biopax/81/170941#Complex355
# 134	42.94872450828552	http://www.reactome.org/biopax/81/170941#Complex358
# 135	43.10575723648071	http://www.reactome.org/biopax/81/170941#Complex359
# 136	43.19772148132324	http://www.reactome.org/biopax/81/170941#Complex360
# 137	43.32672166824341	http://www.reactome.org/biopax/81/170941#Complex361
# 138	43.4337420463562	http://www.reactome.org/biopax/81/170941#Complex374
# 139	43.56077980995178	http://www.reactome.org/biopax/81/170941#Complex375
# 140	43.651803970336914	http://www.reactome.org/biopax/81/170941#Complex377
# 141	43.75873112678528	http://www.reactome.org/biopax/81/170941#Complex378
# 142	43.89608144760132	http://www.reactome.org/biopax/81/170941#Complex379
# 143	44.00927186012268	http://www.reactome.org/biopax/81/170941#Complex380
# 144	44.08812165260315	http://www.reactome.org/biopax/81/170941#Complex381
# 145	44.20339846611023	http://www.reactome.org/biopax/81/170941#Complex384
# 146	44.26929688453674	http://www.reactome.org/biopax/81/170941#Complex385
# 147	44.33481740951538	http://www.reactome.org/biopax/81/170941#Complex387
# 148	44.39628291130066	http://www.reactome.org/biopax/81/170941#Complex389
# 149	44.49585843086243	http://www.reactome.org/biopax/81/170941#Complex390
# 150	44.620824575424194	http://www.reactome.org/biopax/81/170941#Complex392
# 151	44.74213671684265	http://www.reactome.org/biopax/81/170941#Complex393
# 152	44.893200635910034	http://www.reactome.org/biopax/81/170941#Complex409
# 153	44.97976303100586	http://www.reactome.org/biopax/81/170941#Complex412
# 154	45.100955963134766	http://www.reactome.org/biopax/81/170941#Complex413
# 155	45.212926387786865	http://www.reactome.org/biopax/81/170941#Complex414
# 156	45.322343826293945	http://www.reactome.org/biopax/81/170941#Complex415
# 157	45.52885985374451	http://www.reactome.org/biopax/81/170941#Complex417
# 158	45.70241975784302	http://www.reactome.org/biopax/81/170941#Complex418
# 159	45.861724853515625	http://www.reactome.org/biopax/81/170941#Complex419
# 160	46.01743197441101	http://www.reactome.org/biopax/81/170941#Complex421
# 161	46.10285663604736	http://www.reactome.org/biopax/81/170941#Complex424
# 162	46.21783685684204	http://www.reactome.org/biopax/81/170941#Complex425
# 163	46.32482647895813	http://www.reactome.org/biopax/81/170941#Complex426
# 164	46.42927956581116	http://www.reactome.org/biopax/81/170941#Complex430
# 165	46.53027033805847	http://www.reactome.org/biopax/81/170941#Complex435
# 166	46.7133150100708	http://www.reactome.org/biopax/81/170941#Complex436
# 167	46.822131395339966	http://www.reactome.org/biopax/81/170941#Complex440
# 168	46.905409812927246	http://www.reactome.org/biopax/81/170941#Complex442
# 169	47.01476049423218	http://www.reactome.org/biopax/81/170941#Complex443
# 170	47.10472822189331	http://www.reactome.org/biopax/81/170941#Complex444
# 171	47.22830414772034	http://www.reactome.org/biopax/81/170941#Complex445
# 172	47.32466149330139	http://www.reactome.org/biopax/81/170941#Complex446
# 173	47.51131868362427	http://www.reactome.org/biopax/81/170941#Complex447
# 174	47.687732458114624	http://www.reactome.org/biopax/81/170941#Complex448
# 175	47.828269958496094	http://www.reactome.org/biopax/81/170941#Complex449
# 176	47.9784255027771	http://www.reactome.org/biopax/81/170941#Complex450
# 177	48.27311396598816	http://www.reactome.org/biopax/81/170941#Complex454
# 178	48.63825488090515	http://www.reactome.org/biopax/81/170941#Complex452
# 179	48.70729613304138	http://www.reactome.org/biopax/81/170941#Complex456
# 180	48.98497176170349	http://www.reactome.org/biopax/81/170941#Complex461
# 181	49.32546782493591	http://www.reactome.org/biopax/81/170941#Complex457
# 182	49.447083711624146	http://www.reactome.org/biopax/81/170941#Complex459
# 183	49.554083824157715	http://www.reactome.org/biopax/81/170941#Complex462
# 184	49.92151761054993	http://www.reactome.org/biopax/81/170941#Complex463
# 185	50.214839696884155	http://www.reactome.org/biopax/81/170941#Complex464
# 186	50.34952449798584	http://www.reactome.org/biopax/81/170941#Complex466
# 187	50.658287525177	http://www.reactome.org/biopax/81/170941#Complex468
# 188	51.4266881942749	http://www.reactome.org/biopax/81/170941#Complex469
# 189	52.12549138069153	http://www.reactome.org/biopax/81/170941#Complex472
# 190	52.83237314224243	http://www.reactome.org/biopax/81/170941#Complex470
# 191	53.48084759712219	http://www.reactome.org/biopax/81/170941#Complex473
# 192	53.75608825683594	http://www.reactome.org/biopax/81/170941#Complex478
# 193	54.46941018104553	http://www.reactome.org/biopax/81/170941#Complex479
# 194	54.61382484436035	http://www.reactome.org/biopax/81/170941#Complex483
# 195	55.594114780426025	http://www.reactome.org/biopax/81/170941#Complex485
# 196	56.49023914337158	http://www.reactome.org/biopax/81/170941#Complex486
# 197	57.45422124862671	http://www.reactome.org/biopax/81/170941#Complex487
# 198	57.82741689682007	http://www.reactome.org/biopax/81/170941#Complex490
# 199	59.0414400100708	http://www.reactome.org/biopax/81/170941#Complex491
# 200	60.3184540271759	http://www.reactome.org/biopax/81/170941#Complex492
# 201	61.41636657714844	http://www.reactome.org/biopax/81/170941#Complex493
# 202	62.41831851005554	http://www.reactome.org/biopax/81/170941#Complex496
# 203	64.76721668243408	http://www.reactome.org/biopax/81/170941#Complex499
# 204	66.96704030036926	http://www.reactome.org/biopax/81/170941#Complex500
# 205	68.52323293685913	http://www.reactome.org/biopax/81/170941#Complex501
# 206	69.66476440429688	http://www.reactome.org/biopax/81/170941#Complex502
# 207	71.98414087295532	http://www.reactome.org/biopax/81/170941#Complex503
# 208	73.30597639083862	http://www.reactome.org/biopax/81/170941#Complex504
# 209	74.44483971595764	http://www.reactome.org/biopax/81/170941#Complex505
# 210	75.47365498542786	http://www.reactome.org/biopax/81/170941#Complex506
# 211	77.66246294975281	http://www.reactome.org/biopax/81/170941#Complex507
# 212	79.00878429412842	http://www.reactome.org/biopax/81/170941#Complex508
# 213	80.18611717224121	http://www.reactome.org/biopax/81/170941#Complex509
# 214	81.5171012878418	http://www.reactome.org/biopax/81/170941#Complex510
# 215	86.34644651412964	http://www.reactome.org/biopax/81/170941#Complex512
# 216	90.42726135253906	http://www.reactome.org/biopax/81/170941#Complex513
# 217	93.533771276474	http://www.reactome.org/biopax/81/170941#Complex518
# 218	97.20630311965942	http://www.reactome.org/biopax/81/170941#Complex516
# 219	97.33240604400635	http://www.reactome.org/biopax/81/170941#Complex519
# 220	97.65101337432861	http://www.reactome.org/biopax/81/170941#Complex521
# 221	97.72670102119446	http://www.reactome.org/biopax/81/170941#Complex522
# 222	97.88015246391296	http://www.reactome.org/biopax/81/170941#Complex523
# 223	101.02827882766724	http://www.reactome.org/biopax/81/170941#Complex524
# 224	104.14127540588379	http://www.reactome.org/biopax/81/170941#Complex526
# 225	104.32679319381714	http://www.reactome.org/biopax/81/170941#Complex527
# 226	104.44272971153259	http://www.reactome.org/biopax/81/170941#Complex530
# 227	104.65392756462097	http://www.reactome.org/biopax/81/170941#Complex531
# 228	104.86450719833374	http://www.reactome.org/biopax/81/170941#Complex532
# 229	105.10868072509766	http://www.reactome.org/biopax/81/170941#Complex534
# 230	105.2259533405304	http://www.reactome.org/biopax/81/170941#Complex538
# 231	105.310231924057	http://www.reactome.org/biopax/81/170941#Complex542
# 232	105.3967399597168	http://www.reactome.org/biopax/81/170941#Complex543
# 233	105.51199579238892	http://www.reactome.org/biopax/81/170941#Complex544
# 234	105.61495423316956	http://www.reactome.org/biopax/81/170941#Complex546
# 235	105.71423673629761	http://www.reactome.org/biopax/81/170941#Complex553
# 236	105.8145740032196	http://www.reactome.org/biopax/81/170941#Complex554
# 237	105.92342901229858	http://www.reactome.org/biopax/81/170941#Complex555
# 238	106.025075674057	http://www.reactome.org/biopax/81/170941#Complex556
# 239	106.13584327697754	http://www.reactome.org/biopax/81/170941#Complex565
# 240	106.22478199005127	http://www.reactome.org/biopax/81/170941#Complex567
# 241	106.36631608009338	http://www.reactome.org/biopax/81/170941#Complex569
# 242	106.51759648323059	http://www.reactome.org/biopax/81/170941#Complex573
# 243	106.76023054122925	http://www.reactome.org/biopax/81/170941#Complex574
# 244	106.95068573951721	http://www.reactome.org/biopax/81/170941#Complex576
# 245	107.19419574737549	http://www.reactome.org/biopax/81/170941#Complex577
# 246	107.40945839881897	http://www.reactome.org/biopax/81/170941#Complex580
# 247	107.65233659744263	http://www.reactome.org/biopax/81/170941#Complex582
# 248	107.85476756095886	http://www.reactome.org/biopax/81/170941#Complex581
# 249	107.95478987693787	http://www.reactome.org/biopax/81/170941#Complex583
# 250	108.2866051197052	http://www.reactome.org/biopax/81/170941#Complex584
# 251	108.5668842792511	http://www.reactome.org/biopax/81/170941#Complex586
# 252	108.6659185886383	http://www.reactome.org/biopax/81/170941#Complex588
# 253	108.76574611663818	http://www.reactome.org/biopax/81/170941#Complex590
# 254	108.8353111743927	http://www.reactome.org/biopax/81/170941#Complex591
# 255	108.90827059745789	http://www.reactome.org/biopax/81/170941#Complex593
# 256	109.00669574737549	http://www.reactome.org/biopax/81/170941#Complex601
# 257	109.10075378417969	http://www.reactome.org/biopax/81/170941#Complex670
# 258	109.17337369918823	http://www.reactome.org/biopax/81/170941#Complex672
# 259	109.23987603187561	http://www.reactome.org/biopax/81/170941#Complex705
# 260	109.31064462661743	http://www.reactome.org/biopax/81/170941#Complex707
# 261	109.38155746459961	http://www.reactome.org/biopax/81/170941#Complex718
# 262	109.53163385391235	http://www.reactome.org/biopax/81/170941#Complex722
# 263	109.7293643951416	http://www.reactome.org/biopax/81/170941#Complex731
# 264	109.79400372505188	http://www.reactome.org/biopax/81/170941#Complex737
# 265	109.85562419891357	http://www.reactome.org/biopax/81/170941#Complex744
# 266	109.94578504562378	http://www.reactome.org/biopax/81/170941#Complex786
# 267	110.04291915893555	http://www.reactome.org/biopax/81/170941#Complex815
# 268	110.10809898376465	http://www.reactome.org/biopax/81/170941#Complex819
# 269	110.1717917919159	http://www.reactome.org/biopax/81/170941#Complex821
# 270	110.23504686355591	http://www.reactome.org/biopax/81/170941#Complex823
# 271	110.33577084541321	http://www.reactome.org/biopax/81/170941#Complex836
# 272	110.42269611358643	http://www.reactome.org/biopax/81/170941#Complex849
# 273	110.54044032096863	http://www.reactome.org/biopax/81/170941#Complex852
# 274	110.84339809417725	http://www.reactome.org/biopax/81/170941#Complex855
# 275	111.1715977191925	http://www.reactome.org/biopax/81/170941#Complex853
# 276	111.4247899055481	http://www.reactome.org/biopax/81/170941#Complex858
# 277	111.75170087814331	http://www.reactome.org/biopax/81/170941#Complex860
# 278	112.17467880249023	http://www.reactome.org/biopax/81/170941#Complex864
# 279	112.38448143005371	http://www.reactome.org/biopax/81/170941#Complex865
# 280	112.65874862670898	http://www.reactome.org/biopax/81/170941#Complex867
# 281	112.90438294410706	http://www.reactome.org/biopax/81/170941#Complex870
# 282	112.97323560714722	http://www.reactome.org/biopax/81/170941#Complex877
# 283	113.19552063941956	http://www.reactome.org/biopax/81/170941#Complex878
# 284	113.26570057868958	http://www.reactome.org/biopax/81/170941#Complex883
# 285	113.45293831825256	http://www.reactome.org/biopax/81/170941#Complex887
# 286	113.52363920211792	http://www.reactome.org/biopax/81/170941#Complex898
# 287	113.61375427246094	http://www.reactome.org/biopax/81/170941#Complex899
# 288	113.94197082519531	http://www.reactome.org/biopax/81/170941#Complex902
# 289	114.42666411399841	http://www.reactome.org/biopax/81/170941#Complex907
# 290	114.49222469329834	http://www.reactome.org/biopax/81/170941#Complex909
# 291	114.56285738945007	http://www.reactome.org/biopax/81/170941#Complex911
# 292	114.63653421401978	http://www.reactome.org/biopax/81/170941#Complex954
# 293	114.76500678062439	http://www.reactome.org/biopax/81/170941#Complex959
# 294	114.9727942943573	http://www.reactome.org/biopax/81/170941#Complex963
# 295	115.21632862091064	http://www.reactome.org/biopax/81/170941#Complex960
# 296	115.40432071685791	http://www.reactome.org/biopax/81/170941#Complex965
# 297	115.62380957603455	http://www.reactome.org/biopax/81/170941#Complex968
# 298	115.69931983947754	http://www.reactome.org/biopax/81/170941#Complex970
# 299	115.7818455696106	http://www.reactome.org/biopax/81/170941#Complex989
# 300	115.85408353805542	http://www.reactome.org/biopax/81/170941#Complex999
# 301	115.92812633514404	http://www.reactome.org/biopax/81/170941#Complex1003
# 302	116.02621459960938	http://www.reactome.org/biopax/81/170941#Complex1007
# 303	116.07455921173096	http://www.reactome.org/biopax/81/170941#Complex1021
# 304	116.28112959861755	http://www.reactome.org/biopax/81/170941#Complex1041
# 305	116.3949863910675	http://www.reactome.org/biopax/81/170941#Complex1058
# 306	116.49892997741699	http://www.reactome.org/biopax/81/170941#Complex1060
# 307	116.59973645210266	http://www.reactome.org/biopax/81/170941#Complex1061
# 308	116.67174172401428	http://www.reactome.org/biopax/81/170941#Complex1069
# 309	116.74138355255127	http://www.reactome.org/biopax/81/170941#Complex1071
# 310	116.80460000038147	http://www.reactome.org/biopax/81/170941#Complex1075
# 311	116.88286709785461	http://www.reactome.org/biopax/81/170941#Complex1082
# 312	117.13812232017517	http://www.reactome.org/biopax/81/170941#Complex1084
# 313	117.36066484451294	http://www.reactome.org/biopax/81/170941#Complex1086
# 314	117.56959939002991	http://www.reactome.org/biopax/81/170941#Complex1106
# 315	117.67196369171143	http://www.reactome.org/biopax/81/170941#Complex1112
# 316	117.74250078201294	http://www.reactome.org/biopax/81/170941#Complex1114
# 317	117.90367817878723	http://www.reactome.org/biopax/81/170941#Complex1118
# 318	118.0642020702362	http://www.reactome.org/biopax/81/170941#Complex1119
# 319	118.20865678787231	http://www.reactome.org/biopax/81/170941#Complex1123
# 320	118.34607529640198	http://www.reactome.org/biopax/81/170941#Complex1134
# 321	118.50296545028687	http://www.reactome.org/biopax/81/170941#Complex1147
# 322	118.58980512619019	http://www.reactome.org/biopax/81/170941#Complex1150
# 323	126.05680990219116	http://www.reactome.org/biopax/81/170941#Complex1154
# 324	129.15020561218262	http://www.reactome.org/biopax/81/170941#Complex1155
# 325	129.26613664627075	http://www.reactome.org/biopax/81/170941#Complex1156
# 326	129.42422795295715	http://www.reactome.org/biopax/81/170941#Complex1157
# 327	133.0934693813324	http://www.reactome.org/biopax/81/170941#Complex1160
# 328	133.2218382358551	http://www.reactome.org/biopax/81/170941#Complex1161
# 329	138.12539792060852	http://www.reactome.org/biopax/81/170941#Complex1162
# 330	146.14384150505066	http://www.reactome.org/biopax/81/170941#Complex1165
# 331	153.41006684303284	http://www.reactome.org/biopax/81/170941#Complex1166
# 332	155.01507353782654	http://www.reactome.org/biopax/81/170941#Complex1168
# 333	155.12341570854187	http://www.reactome.org/biopax/81/170941#Complex1169
# 334	155.38688349723816	http://www.reactome.org/biopax/81/170941#Complex1171
# 335	159.340313911438	http://www.reactome.org/biopax/81/170941#Complex1172
# 336	163.37952637672424	http://www.reactome.org/biopax/81/170941#Complex1174
# 337	171.68606519699097	http://www.reactome.org/biopax/81/170941#Complex1175
# 338	181.92615032196045	http://www.reactome.org/biopax/81/170941#Complex1180
# 339	182.0537507534027	http://www.reactome.org/biopax/81/170941#Complex1181
# 340	182.15935349464417	http://www.reactome.org/biopax/81/170941#Complex1184
# 341	182.28254580497742	http://www.reactome.org/biopax/81/170941#Complex1188
# 342	182.61466002464294	http://www.reactome.org/biopax/81/170941#Complex1189
# 343	182.97066640853882	http://www.reactome.org/biopax/81/170941#Complex1190
# 344	183.34826493263245	http://www.reactome.org/biopax/81/170941#Complex1204
# 345	183.45500469207764	http://www.reactome.org/biopax/81/170941#Complex1206
# 346	183.59637594223022	http://www.reactome.org/biopax/81/170941#Complex1222
# 347	183.76138472557068	http://www.reactome.org/biopax/81/170941#Complex1225
# 348	183.9812958240509	http://www.reactome.org/biopax/81/170941#Complex1234
# 349	184.87949800491333	http://www.reactome.org/biopax/81/170941#Complex1235
# 350	185.6142544746399	http://www.reactome.org/biopax/81/170941#Complex1238
# 351	185.76030731201172	http://www.reactome.org/biopax/81/170941#Complex1241
# 352	185.98232460021973	http://www.reactome.org/biopax/81/170941#Complex1243
# 353	186.07451033592224	http://www.reactome.org/biopax/81/170941#Complex1245
# 354	186.20278096199036	http://www.reactome.org/biopax/81/170941#Complex1247
# 355	186.40771317481995	http://www.reactome.org/biopax/81/170941#Complex1248
# 356	186.58579540252686	http://www.reactome.org/biopax/81/170941#Complex1250
# 357	186.81022357940674	http://www.reactome.org/biopax/81/170941#Complex1253
# 358	187.23413014411926	http://www.reactome.org/biopax/81/170941#Complex1260
# 359	187.30047130584717	http://www.reactome.org/biopax/81/170941#Complex1262
# 360	188.0531406402588	http://www.reactome.org/biopax/81/170941#Complex1263
# 361	188.6424376964569	http://www.reactome.org/biopax/81/170941#Complex1270
# 362	188.97968888282776	http://www.reactome.org/biopax/81/170941#Complex1271
# 363	189.07531428337097	http://www.reactome.org/biopax/81/170941#Complex1274
# 364	189.29265069961548	http://www.reactome.org/biopax/81/170941#Complex1277
# 365	189.81893134117126	http://www.reactome.org/biopax/81/170941#Complex1293
# 366	191.33109712600708	http://www.reactome.org/biopax/81/170941#Complex1279
# 367	191.4480860233307	http://www.reactome.org/biopax/81/170941#Complex1281
# 368	191.7659432888031	http://www.reactome.org/biopax/81/170941#Complex1282
# 369	191.963609457016	http://www.reactome.org/biopax/81/170941#Complex1288
# 370	192.09148693084717	http://www.reactome.org/biopax/81/170941#Complex1286
# 371	192.23326706886292	http://www.reactome.org/biopax/81/170941#Complex1289
# 372	192.32011127471924	http://www.reactome.org/biopax/81/170941#Complex1294
# 373	193.81728386878967	http://www.reactome.org/biopax/81/170941#Complex1316
# 374	195.13147020339966	http://www.reactome.org/biopax/81/170941#Complex1298
# 375	195.85397148132324	http://www.reactome.org/biopax/81/170941#Complex1305
# 376	196.21645641326904	http://www.reactome.org/biopax/81/170941#Complex1306
# 377	196.51113152503967	http://www.reactome.org/biopax/81/170941#Complex1309
# 378	196.62609934806824	http://www.reactome.org/biopax/81/170941#Complex1318
# 379	196.77129650115967	http://www.reactome.org/biopax/81/170941#Complex1321
# 380	196.8767478466034	http://www.reactome.org/biopax/81/170941#Complex1329
# 381	200.41927194595337	http://www.reactome.org/biopax/81/170941#Complex1330
# 382	203.29634833335876	http://www.reactome.org/biopax/81/170941#Complex1344
# 383	206.36265754699707	http://www.reactome.org/biopax/81/170941#Complex1363
# 384	206.47942662239075	http://www.reactome.org/biopax/81/170941#Complex1365
# 385	206.59414100646973	http://www.reactome.org/biopax/81/170941#Complex1372
# 386	206.73066353797913	http://www.reactome.org/biopax/81/170941#Complex1374
# 387	206.84325790405273	http://www.reactome.org/biopax/81/170941#Complex1377
# 388	206.93434190750122	http://www.reactome.org/biopax/81/170941#Complex1379
# 389	207.02920722961426	http://www.reactome.org/biopax/81/170941#Complex1385
# 390	207.12347316741943	http://www.reactome.org/biopax/81/170941#Complex1388
# 391	207.26764726638794	http://www.reactome.org/biopax/81/170941#Complex1390
# 392	207.43674969673157	http://www.reactome.org/biopax/81/170941#Complex1392
# 393	207.51490831375122	http://www.reactome.org/biopax/81/170941#Complex1394
# 394	207.6319978237152	http://www.reactome.org/biopax/81/170941#Complex1396
# 395	207.96649408340454	http://www.reactome.org/biopax/81/170941#Complex1399
# 396	208.25517749786377	http://www.reactome.org/biopax/81/170941#Complex1402
# 397	208.38336157798767	http://www.reactome.org/biopax/81/170941#Complex1404
# 398	208.59784579277039	http://www.reactome.org/biopax/81/170941#Complex1406
# 399	208.7220015525818	http://www.reactome.org/biopax/81/170941#Complex1410
# 400	208.82289958000183	http://www.reactome.org/biopax/81/170941#Complex1412
# 401	208.95393419265747	http://www.reactome.org/biopax/81/170941#Complex1413
# 402	209.12401628494263	http://www.reactome.org/biopax/81/170941#Complex1414
# 403	209.28325152397156	http://www.reactome.org/biopax/81/170941#Complex1417
# 404	209.48351550102234	http://www.reactome.org/biopax/81/170941#Complex1420
# 405	209.71517896652222	http://www.reactome.org/biopax/81/170941#Complex1422
# 406	209.86253595352173	http://www.reactome.org/biopax/81/170941#Complex1424
# 407	210.04665875434875	http://www.reactome.org/biopax/81/170941#Complex1425
# 408	210.4033670425415	http://www.reactome.org/biopax/81/170941#Complex1426
# 409	210.62397360801697	http://www.reactome.org/biopax/81/170941#Complex1428
# 410	210.77897357940674	http://www.reactome.org/biopax/81/170941#Complex1430
# 411	211.04187726974487	http://www.reactome.org/biopax/81/170941#Complex1431
# 412	211.23458409309387	http://www.reactome.org/biopax/81/170941#Complex1434
# 413	211.53641533851624	http://www.reactome.org/biopax/81/170941#Complex1435
# 414	211.73910284042358	http://www.reactome.org/biopax/81/170941#Complex1437
# 415	212.1027009487152	http://www.reactome.org/biopax/81/170941#Complex1440
# 416	212.385151386261	http://www.reactome.org/biopax/81/170941#Complex1438
# 417	212.60278868675232	http://www.reactome.org/biopax/81/170941#Complex1444
# 418	212.81775188446045	http://www.reactome.org/biopax/81/170941#Complex1445
# 419	213.01740264892578	http://www.reactome.org/biopax/81/170941#Complex1446
# 420	213.33074140548706	http://www.reactome.org/biopax/81/170941#Complex1448
# 421	213.6305115222931	http://www.reactome.org/biopax/81/170941#Complex1453
# 422	213.71555185317993	http://www.reactome.org/biopax/81/170941#Complex1456
# 423	213.8319752216339	http://www.reactome.org/biopax/81/170941#Complex1459
# 424	213.99532675743103	http://www.reactome.org/biopax/81/170941#Complex1462
# 425	214.18157124519348	http://www.reactome.org/biopax/81/170941#Complex1465
# 426	214.33154487609863	http://www.reactome.org/biopax/81/170941#Complex1467
# 427	214.46283221244812	http://www.reactome.org/biopax/81/170941#Complex1469
# 428	215.72568440437317	http://www.reactome.org/biopax/81/170941#Complex1474
# 429	215.91161131858826	http://www.reactome.org/biopax/81/170941#Complex1476
# 430	216.10784935951233	http://www.reactome.org/biopax/81/170941#Complex1478
# 431	216.20036101341248	http://www.reactome.org/biopax/81/170941#Complex1479
# 432	216.2962040901184	http://www.reactome.org/biopax/81/170941#Complex1481
# 433	216.59661030769348	http://www.reactome.org/biopax/81/170941#Complex1487
# 434	216.89193654060364	http://www.reactome.org/biopax/81/170941#Complex1488
# 435	217.01400232315063	http://www.reactome.org/biopax/81/170941#Complex1490
# 436	217.2130570411682	http://www.reactome.org/biopax/81/170941#Complex1493
# 437	217.3380970954895	http://www.reactome.org/biopax/81/170941#Complex1494
# 438	217.4337179660797	http://www.reactome.org/biopax/81/170941#Complex1495
# 439	217.59973073005676	http://www.reactome.org/biopax/81/170941#Complex1496
# 440	217.73691487312317	http://www.reactome.org/biopax/81/170941#Complex1497
# 441	218.12601375579834	http://www.reactome.org/biopax/81/170941#Complex1499
# 442	218.68772220611572	http://www.reactome.org/biopax/81/170941#Complex1498
# 443	218.81151223182678	http://www.reactome.org/biopax/81/170941#Complex1500
# 444	219.22338318824768	http://www.reactome.org/biopax/81/170941#Complex1501
# 445	219.35566425323486	http://www.reactome.org/biopax/81/170941#Complex1502
# 446	220.0561978816986	http://www.reactome.org/biopax/81/170941#Complex1516
# 447	220.17583012580872	http://www.reactome.org/biopax/81/170941#Complex1503
# 448	220.38456296920776	http://www.reactome.org/biopax/81/170941#Complex1506
# 449	220.50836420059204	http://www.reactome.org/biopax/81/170941#Complex1517
# 450	220.69445419311523	http://www.reactome.org/biopax/81/170941#Complex1520
# 451	220.82564759254456	http://www.reactome.org/biopax/81/170941#Complex1521
# 452	220.96579098701477	http://www.reactome.org/biopax/81/170941#Complex1525
# 453	221.13216638565063	http://www.reactome.org/biopax/81/170941#Complex1527
# 454	221.32261300086975	http://www.reactome.org/biopax/81/170941#Complex1529
# 455	221.639404296875	http://www.reactome.org/biopax/81/170941#Complex1532
# 456	221.97509050369263	http://www.reactome.org/biopax/81/170941#Complex1537
# 457	222.14503598213196	http://www.reactome.org/biopax/81/170941#Complex1538
# 458	222.3151044845581	http://www.reactome.org/biopax/81/170941#Complex1543
# 459	222.6696174144745	http://www.reactome.org/biopax/81/170941#Complex1546
# 460	222.92621850967407	http://www.reactome.org/biopax/81/170941#Complex1547
# 461	223.4732596874237	http://www.reactome.org/biopax/81/170941#Complex1552
# 462	223.96615839004517	http://www.reactome.org/biopax/81/170941#Complex1548
# 463	224.45656776428223	http://www.reactome.org/biopax/81/170941#Complex1554
# 464	224.65062928199768	http://www.reactome.org/biopax/81/170941#Complex1558
# 465	224.81882190704346	http://www.reactome.org/biopax/81/170941#Complex1559
# 466	225.03454303741455	http://www.reactome.org/biopax/81/170941#Complex1571
# 467	225.13277339935303	http://www.reactome.org/biopax/81/170941#Complex1574
# 468	225.22513484954834	http://www.reactome.org/biopax/81/170941#Complex1578
# 469	225.32001733779907	http://www.reactome.org/biopax/81/170941#Complex1581
# 470	225.426011800766	http://www.reactome.org/biopax/81/170941#Complex1584
# 471	225.5210473537445	http://www.reactome.org/biopax/81/170941#Complex1587
# 472	225.61727666854858	http://www.reactome.org/biopax/81/170941#Complex1590
# 473	225.7111279964447	http://www.reactome.org/biopax/81/170941#Complex1593
# 474	225.80666971206665	http://www.reactome.org/biopax/81/170941#Complex1611
# 475	226.2968611717224	http://www.reactome.org/biopax/81/170941#Complex1612
# 476	227.77155256271362	http://www.reactome.org/biopax/81/170941#Complex1616
# 477	229.0728874206543	http://www.reactome.org/biopax/81/170941#Complex1613
# 478	229.27909994125366	http://www.reactome.org/biopax/81/170941#Complex1618
# 479	229.3804383277893	http://www.reactome.org/biopax/81/170941#Complex1619
# 480	229.55291271209717	http://www.reactome.org/biopax/81/170941#Complex1630
# 481	229.6628062725067	http://www.reactome.org/biopax/81/170941#Complex1632
# 482	230.147686958313	http://www.reactome.org/biopax/81/170941#Complex1635
# 483	232.77864360809326	http://www.reactome.org/biopax/81/170941#Complex1645
# 484	235.2677628993988	http://www.reactome.org/biopax/81/170941#Complex1636
# 485	235.35496282577515	http://www.reactome.org/biopax/81/170941#Complex1638
# 486	236.3636872768402	http://www.reactome.org/biopax/81/170941#Complex1639
# 487	236.8424973487854	http://www.reactome.org/biopax/81/170941#Complex1646
# 488	239.32885789871216	http://www.reactome.org/biopax/81/170941#Complex1647
# 489	241.79877543449402	http://www.reactome.org/biopax/81/170941#Complex1648
# 490	243.09193539619446	http://www.reactome.org/biopax/81/170941#Complex1649
# 491	243.64527940750122	http://www.reactome.org/biopax/81/170941#Complex1657
# 492	243.77028059959412	http://www.reactome.org/biopax/81/170941#Complex1668
# 493	243.86454796791077	http://www.reactome.org/biopax/81/170941#Complex1669
# 494	246.7271649837494	http://www.reactome.org/biopax/81/170941#Complex1671
# 495	247.30976057052612	http://www.reactome.org/biopax/81/170941#Complex1674
# 496	248.5917682647705	http://www.reactome.org/biopax/81/170941#Complex1675
# 497	251.71913886070251	http://www.reactome.org/biopax/81/170941#Complex1676
# 498	252.80491137504578	http://www.reactome.org/biopax/81/170941#Complex1677
# 499	253.66424322128296	http://www.reactome.org/biopax/81/170941#Complex1678
# 500	254.37608289718628	http://www.reactome.org/biopax/81/170941#Complex1679
# 501	254.9071922302246	http://www.reactome.org/biopax/81/170941#Complex1681
# 502	258.4348773956299	http://www.reactome.org/biopax/81/170941#Complex1682
# 503	261.4376564025879	http://www.reactome.org/biopax/81/170941#Complex1683
# 504	263.18066668510437	http://www.reactome.org/biopax/81/170941#Complex1684
# 505	264.00637793540955	http://www.reactome.org/biopax/81/170941#Complex1685
# 506	264.5691342353821	http://www.reactome.org/biopax/81/170941#Complex1686
# 507	266.39516496658325	http://www.reactome.org/biopax/81/170941#Complex1687
# 508	269.4000539779663	http://www.reactome.org/biopax/81/170941#Complex1688
# 509	270.40056133270264	http://www.reactome.org/biopax/81/170941#Complex1689
# 510	273.0340733528137	http://www.reactome.org/biopax/81/170941#Complex1690
# 511	275.6735506057739	http://www.reactome.org/biopax/81/170941#Complex1691
# 512	278.3005635738373	http://www.reactome.org/biopax/81/170941#Complex1692
# 513	279.4927136898041	http://www.reactome.org/biopax/81/170941#Complex1693
# 514	280.57741928100586	http://www.reactome.org/biopax/81/170941#Complex1694
# 515	281.7576320171356	http://www.reactome.org/biopax/81/170941#Complex1695
# 516	282.8693974018097	http://www.reactome.org/biopax/81/170941#Complex1696
# 517	283.3354687690735	http://www.reactome.org/biopax/81/170941#Complex1698
# 518	284.5036790370941	http://www.reactome.org/biopax/81/170941#Complex1699
# 519	285.75146412849426	http://www.reactome.org/biopax/81/170941#Complex1700
# 520	286.3938932418823	http://www.reactome.org/biopax/81/170941#Complex1701
# 521	286.93234157562256	http://www.reactome.org/biopax/81/170941#Complex1702
# 522	287.37359595298767	http://www.reactome.org/biopax/81/170941#Complex1705
# 523	287.6418445110321	http://www.reactome.org/biopax/81/170941#Complex1703
# 524	287.76630115509033	http://www.reactome.org/biopax/81/170941#Complex1704
# 525	287.8556184768677	http://www.reactome.org/biopax/81/170941#Complex1708
# 526	288.2663953304291	http://www.reactome.org/biopax/81/170941#Complex1709
# 527	288.3557198047638	http://www.reactome.org/biopax/81/170941#Complex1710
# 528	290.63344860076904	http://www.reactome.org/biopax/81/170941#Complex1716
# 529	293.3665997982025	http://www.reactome.org/biopax/81/170941#Complex1711
# 530	294.7586796283722	http://www.reactome.org/biopax/81/170941#Complex1713
# 531	295.062127828598	http://www.reactome.org/biopax/81/170941#Complex1717
# 532	296.3183214664459	http://www.reactome.org/biopax/81/170941#Complex1719
# 533	300.6102862358093	http://www.reactome.org/biopax/81/170941#Complex1724
# 534	304.9057364463806	http://www.reactome.org/biopax/81/170941#Complex1720
# 535	306.6239457130432	http://www.reactome.org/biopax/81/170941#Complex1726
# 536	308.2757956981659	http://www.reactome.org/biopax/81/170941#Complex1728
# 537	313.4966604709625	http://www.reactome.org/biopax/81/170941#Complex1730
# 538	318.24322962760925	http://www.reactome.org/biopax/81/170941#Complex1731
# 539	318.4292323589325	http://www.reactome.org/biopax/81/170941#Complex1729
# 540	318.62166833877563	http://www.reactome.org/biopax/81/170941#Complex1735
# 541	318.89652919769287	http://www.reactome.org/biopax/81/170941#Complex1737
# 542	319.28666496276855	http://www.reactome.org/biopax/81/170941#Complex1738
# 543	319.91704416275024	http://www.reactome.org/biopax/81/170941#Complex1742
# 544	321.40206599235535	http://www.reactome.org/biopax/81/170941#Complex1743
# 545	321.659649848938	http://www.reactome.org/biopax/81/170941#Complex1744
# 546	322.0527882575989	http://www.reactome.org/biopax/81/170941#Complex1745
# 547	323.2333016395569	http://www.reactome.org/biopax/81/170941#Complex1748
# 548	323.3535478115082	http://www.reactome.org/biopax/81/170941#Complex1751
# 549	323.6191895008087	http://www.reactome.org/biopax/81/170941#Complex1752
# 550	323.89089727401733	http://www.reactome.org/biopax/81/170941#Complex1755
# 551	323.97983717918396	http://www.reactome.org/biopax/81/170941#Complex1761
# 552	324.07530999183655	http://www.reactome.org/biopax/81/170941#Complex1763
# 553	324.16540908813477	http://www.reactome.org/biopax/81/170941#Complex1768
# 554	324.25803661346436	http://www.reactome.org/biopax/81/170941#Complex1769
# 555	324.4745464324951	http://www.reactome.org/biopax/81/170941#Complex1777
# 556	324.6852126121521	http://www.reactome.org/biopax/81/170941#Complex1774
# 557	324.84663367271423	http://www.reactome.org/biopax/81/170941#Complex1782
# 558	325.0571312904358	http://www.reactome.org/biopax/81/170941#Complex1798
# 559	325.1626236438751	http://www.reactome.org/biopax/81/170941#Complex1799
# 560	325.26838731765747	http://www.reactome.org/biopax/81/170941#Complex1800
# 561	325.3796796798706	http://www.reactome.org/biopax/81/170941#Complex1805
# 562	325.5980451107025	http://www.reactome.org/biopax/81/170941#Complex1808
# 563	325.86341285705566	http://www.reactome.org/biopax/81/170941#Complex1806
# 564	326.0056302547455	http://www.reactome.org/biopax/81/170941#Complex1809
# 565	326.14156198501587	http://www.reactome.org/biopax/81/170941#Complex1810
# 566	326.24844336509705	http://www.reactome.org/biopax/81/170941#Complex1814
# 567	326.33232593536377	http://www.reactome.org/biopax/81/170941#Complex1819
# 568	326.5125732421875	http://www.reactome.org/biopax/81/170941#Complex1820
# 569	326.6456527709961	http://www.reactome.org/biopax/81/170941#Complex1822
# 570	326.78237104415894	http://www.reactome.org/biopax/81/170941#Complex1823
# 571	326.8834116458893	http://www.reactome.org/biopax/81/170941#Complex1827
# 572	326.98508167266846	http://www.reactome.org/biopax/81/170941#Complex1829
# 573	327.1289973258972	http://www.reactome.org/biopax/81/170941#Complex1830
# 574	327.3025608062744	http://www.reactome.org/biopax/81/170941#Complex1836
# 575	327.4528474807739	http://www.reactome.org/biopax/81/170941#Complex1838
# 576	327.61291885375977	http://www.reactome.org/biopax/81/170941#Complex1840
# 577	327.7573609352112	http://www.reactome.org/biopax/81/170941#Complex1841
# 578	327.87695837020874	http://www.reactome.org/biopax/81/170941#Complex1842
# 579	327.9640226364136	http://www.reactome.org/biopax/81/170941#Complex1849
# 580	328.18059492111206	http://www.reactome.org/biopax/81/170941#Complex1853
# 581	328.37695121765137	http://www.reactome.org/biopax/81/170941#Complex1851
# 582	328.5019829273224	http://www.reactome.org/biopax/81/170941#Complex1862
# 583	328.67100262641907	http://www.reactome.org/biopax/81/170941#Complex1865
# 584	328.8750545978546	http://www.reactome.org/biopax/81/170941#Complex1863
# 585	328.96795773506165	http://www.reactome.org/biopax/81/170941#Complex1866
# 586	329.1516344547272	http://www.reactome.org/biopax/81/170941#Complex1867
# 587	329.3343904018402	http://www.reactome.org/biopax/81/170941#Complex1868
# 588	329.50010919570923	http://www.reactome.org/biopax/81/170941#Complex1869
# 589	329.7148087024689	http://www.reactome.org/biopax/81/170941#Complex1870
# 590	330.455899477005	http://www.reactome.org/biopax/81/170941#Complex1875
# 591	331.1236877441406	http://www.reactome.org/biopax/81/170941#Complex1871
# 592	331.2330870628357	http://www.reactome.org/biopax/81/170941#Complex1872
# 593	331.28795886039734	http://www.reactome.org/biopax/81/170941#Complex1876
# 594	331.63490533828735	http://www.reactome.org/biopax/81/170941#Complex1882
# 595	332.04125809669495	http://www.reactome.org/biopax/81/170941#Complex1877
# 596	332.3779089450836	http://www.reactome.org/biopax/81/170941#Complex1878
# 597	332.55807161331177	http://www.reactome.org/biopax/81/170941#Complex1879
# 598	332.7147843837738	http://www.reactome.org/biopax/81/170941#Complex1884
# 599	332.8032400608063	http://www.reactome.org/biopax/81/170941#Complex1885
# 600	332.90578508377075	http://www.reactome.org/biopax/81/170941#Complex1891
# 601	332.99986839294434	http://www.reactome.org/biopax/81/170941#Complex1894
# 602	333.0976858139038	http://www.reactome.org/biopax/81/170941#Complex1895
# 603	333.19799995422363	http://www.reactome.org/biopax/81/170941#Complex1898
# 604	333.40266609191895	http://www.reactome.org/biopax/81/170941#Complex1901
# 605	333.6489815711975	http://www.reactome.org/biopax/81/170941#Complex1899
# 606	333.7755742073059	http://www.reactome.org/biopax/81/170941#Complex1900
# 607	333.83996534347534	http://www.reactome.org/biopax/81/170941#Complex1902
# 608	334.1030421257019	http://www.reactome.org/biopax/81/170941#Complex1907
# 609	334.41476559638977	http://www.reactome.org/biopax/81/170941#Complex1903
# 610	334.6417272090912	http://www.reactome.org/biopax/81/170941#Complex1906
# 611	334.7589635848999	http://www.reactome.org/biopax/81/170941#Complex1908
# 612	335.0138964653015	http://www.reactome.org/biopax/81/170941#Complex1909
# 613	335.3038737773895	http://www.reactome.org/biopax/81/170941#Complex1910
# 614	335.62045979499817	http://www.reactome.org/biopax/81/170941#Complex1911
# 615	335.91102838516235	http://www.reactome.org/biopax/81/170941#Complex1912
# 616	336.25256633758545	http://www.reactome.org/biopax/81/170941#Complex1913
# 617	336.4610195159912	http://www.reactome.org/biopax/81/170941#Complex1916
# 618	336.67761397361755	http://www.reactome.org/biopax/81/170941#Complex1922
# 619	336.8016061782837	http://www.reactome.org/biopax/81/170941#Complex1923
# 620	336.9139828681946	http://www.reactome.org/biopax/81/170941#Complex1924
# 621	337.0253963470459	http://www.reactome.org/biopax/81/170941#Complex1935
# 622	337.12804651260376	http://www.reactome.org/biopax/81/170941#Complex1940
# 623	337.2326273918152	http://www.reactome.org/biopax/81/170941#Complex1942
# 624	337.3332750797272	http://www.reactome.org/biopax/81/170941#Complex1943
# 625	337.4293613433838	http://www.reactome.org/biopax/81/170941#Complex1944
# 626	337.52263951301575	http://www.reactome.org/biopax/81/170941#Complex1950
# 627	337.6150391101837	http://www.reactome.org/biopax/81/170941#Complex1958
# 628	337.7172155380249	http://www.reactome.org/biopax/81/170941#Complex1962
# 629	337.81401348114014	http://www.reactome.org/biopax/81/170941#Complex1964
# 630	337.9160418510437	http://www.reactome.org/biopax/81/170941#Complex1970
# 631	338.01372718811035	http://www.reactome.org/biopax/81/170941#Complex1973
# 632	338.11834192276	http://www.reactome.org/biopax/81/170941#Complex1979
# 633	338.21876430511475	http://www.reactome.org/biopax/81/170941#Complex1980
# 634	338.3512713909149	http://www.reactome.org/biopax/81/170941#Complex1981
# 635	338.45812153816223	http://www.reactome.org/biopax/81/170941#Complex1982
# 636	338.64068365097046	http://www.reactome.org/biopax/81/170941#Complex1983
# 637	338.99787640571594	http://www.reactome.org/biopax/81/170941#Complex1985
# 638	339.33892488479614	http://www.reactome.org/biopax/81/170941#Complex1987
# 639	339.750608921051	http://www.reactome.org/biopax/81/170941#Complex1993
# 640	340.2115099430084	http://www.reactome.org/biopax/81/170941#Complex1989
# 641	340.51229095458984	http://www.reactome.org/biopax/81/170941#Complex1994
# 642	340.94993448257446	http://www.reactome.org/biopax/81/170941#Complex1996
# 643	341.2909777164459	http://www.reactome.org/biopax/81/170941#Complex1997
# 644	341.48118233680725	http://www.reactome.org/biopax/81/170941#Complex1998
# 645	341.6740334033966	http://www.reactome.org/biopax/81/170941#Complex2002
# 646	341.7729206085205	http://www.reactome.org/biopax/81/170941#Complex2003
# 647	341.89637780189514	http://www.reactome.org/biopax/81/170941#Complex2005
# 648	341.996550321579	http://www.reactome.org/biopax/81/170941#Complex2006
# 649	342.53828859329224	http://www.reactome.org/biopax/81/170941#Complex2007
# 650	343.14498925209045	http://www.reactome.org/biopax/81/170941#Complex2008
# 651	343.9371678829193	http://www.reactome.org/biopax/81/170941#Complex2009
# 652	344.60813903808594	http://www.reactome.org/biopax/81/170941#Complex2010
# 653	345.14887857437134	http://www.reactome.org/biopax/81/170941#Complex2015
# 654	345.52185821533203	http://www.reactome.org/biopax/81/170941#Complex2018
# 655	345.9458312988281	http://www.reactome.org/biopax/81/170941#Complex2016
# 656	346.197936296463	http://www.reactome.org/biopax/81/170941#Complex2020
# 657	346.32042169570923	http://www.reactome.org/biopax/81/170941#Complex2021
# 658	346.4430046081543	http://www.reactome.org/biopax/81/170941#Complex2023
# 659	346.6006565093994	http://www.reactome.org/biopax/81/170941#Complex2024
# 660	346.8402075767517	http://www.reactome.org/biopax/81/170941#Complex2025
# 661	346.98856806755066	http://www.reactome.org/biopax/81/170941#Complex2030
# 662	348.53165555000305	http://www.reactome.org/biopax/81/170941#Complex2031
# 663	349.92882680892944	http://www.reactome.org/biopax/81/170941#Complex2032
# 664	351.4118182659149	http://www.reactome.org/biopax/81/170941#Complex2033
# 665	352.8564443588257	http://www.reactome.org/biopax/81/170941#Complex2034
# 666	354.4781150817871	http://www.reactome.org/biopax/81/170941#Complex2035
# 667	355.9281086921692	http://www.reactome.org/biopax/81/170941#Complex2039
# 668	356.2721676826477	http://www.reactome.org/biopax/81/170941#Complex2041
# 669	356.7530515193939	http://www.reactome.org/biopax/81/170941#Complex2043
# 670	357.0965712070465	http://www.reactome.org/biopax/81/170941#Complex2045
# 671	357.68715953826904	http://www.reactome.org/biopax/81/170941#Complex2047
# 672	357.7811303138733	http://www.reactome.org/biopax/81/170941#Complex2049
# 673	357.8753869533539	http://www.reactome.org/biopax/81/170941#Complex2051
# 674	358.4571855068207	http://www.reactome.org/biopax/81/170941#Complex2053
# 675	358.5867133140564	http://www.reactome.org/biopax/81/170941#Complex2057
# 676	359.3361465930939	http://www.reactome.org/biopax/81/170941#Complex2060
# 677	359.7395966053009	http://www.reactome.org/biopax/81/170941#Complex2061
# 678	360.0829768180847	http://www.reactome.org/biopax/81/170941#Complex2063
# 679	371.336464881897	http://www.reactome.org/biopax/81/170941#Complex2072
# 680	382.4463167190552	http://www.reactome.org/biopax/81/170941#Complex2064
# 681	393.15513134002686	http://www.reactome.org/biopax/81/170941#Complex2066
# 682	393.29830503463745	http://www.reactome.org/biopax/81/170941#Complex2068
# 683	393.5086553096771	http://www.reactome.org/biopax/81/170941#Complex2069
# 684	393.61995100975037	http://www.reactome.org/biopax/81/170941#Complex2073
# 685	402.1890296936035	http://www.reactome.org/biopax/81/170941#Complex2075
# 686	412.660382270813	http://www.reactome.org/biopax/81/170941#Complex2074
# 687	412.79887557029724	http://www.reactome.org/biopax/81/170941#Complex2076
# 688	415.92840933799744	http://www.reactome.org/biopax/81/170941#Complex2084
# 689	419.35027718544006	http://www.reactome.org/biopax/81/170941#Complex2077
# 690	422.27669167518616	http://www.reactome.org/biopax/81/170941#Complex2085
# 691	425.4810013771057	http://www.reactome.org/biopax/81/170941#Complex2086
# 692	428.54817032814026	http://www.reactome.org/biopax/81/170941#Complex2087
# 693	428.98008728027344	http://www.reactome.org/biopax/81/170941#Complex2091
# 694	429.29176020622253	http://www.reactome.org/biopax/81/170941#Complex2094
# 695	429.55932903289795	http://www.reactome.org/biopax/81/170941#Complex2100
# 696	430.421098947525	http://www.reactome.org/biopax/81/170941#Complex2102
# 697	430.5498785972595	http://www.reactome.org/biopax/81/170941#Complex2104
# 698	430.6859829425812	http://www.reactome.org/biopax/81/170941#Complex2106
# 699	430.7861349582672	http://www.reactome.org/biopax/81/170941#Complex2107
# 700	430.9745020866394	http://www.reactome.org/biopax/81/170941#Complex2108
# 701	431.0949852466583	http://www.reactome.org/biopax/81/170941#Complex2109
# 702	431.26068925857544	http://www.reactome.org/biopax/81/170941#Complex2136
# 703	431.363721370697	http://www.reactome.org/biopax/81/170941#Complex2138
# 704	431.480975151062	http://www.reactome.org/biopax/81/170941#Complex2139
# 705	431.5982675552368	http://www.reactome.org/biopax/81/170941#Complex2140
# 706	431.71868777275085	http://www.reactome.org/biopax/81/170941#Complex2142
# 707	431.84729051589966	http://www.reactome.org/biopax/81/170941#Complex2143
# 708	431.96610283851624	http://www.reactome.org/biopax/81/170941#Complex2144
# 709	432.0865709781647	http://www.reactome.org/biopax/81/170941#Complex2148
# 710	432.2256281375885	http://www.reactome.org/biopax/81/170941#Complex2150
# 711	432.3964195251465	http://www.reactome.org/biopax/81/170941#Complex2154
# 712	432.6488091945648	http://www.reactome.org/biopax/81/170941#Complex2155
# 713	432.84287571907043	http://www.reactome.org/biopax/81/170941#Complex2159
# 714	432.9399390220642	http://www.reactome.org/biopax/81/170941#Complex2161
# 715	433.03684401512146	http://www.reactome.org/biopax/81/170941#Complex2169
# 716	433.2994604110718	http://www.reactome.org/biopax/81/170941#Complex2171
# 717	433.55522656440735	http://www.reactome.org/biopax/81/170941#Complex2170
# 718	433.7756850719452	http://www.reactome.org/biopax/81/170941#Complex2172
# 719	434.0558748245239	http://www.reactome.org/biopax/81/170941#Complex2174
# 720	434.3096010684967	http://www.reactome.org/biopax/81/170941#Complex2175
# 721	434.57272362709045	http://www.reactome.org/biopax/81/170941#Complex2176
# 722	434.6648271083832	http://www.reactome.org/biopax/81/170941#Complex2177
# 723	434.76226711273193	http://www.reactome.org/biopax/81/170941#Complex2180
# 724	434.92183113098145	http://www.reactome.org/biopax/81/170941#Complex2181
# 725	435.0828003883362	http://www.reactome.org/biopax/81/170941#Complex2182
# 726	435.2492711544037	http://www.reactome.org/biopax/81/170941#Complex2185
# 727	435.4069242477417	http://www.reactome.org/biopax/81/170941#Complex2183
# 728	435.5337221622467	http://www.reactome.org/biopax/81/170941#Complex2187
# 729	435.7277681827545	http://www.reactome.org/biopax/81/170941#Complex2188
# 730	436.02967405319214	http://www.reactome.org/biopax/81/170941#Complex2191
# 731	436.37163257598877	http://www.reactome.org/biopax/81/170941#Complex2192
# 732	436.6911449432373	http://www.reactome.org/biopax/81/170941#Complex2194
# 733	436.9939248561859	http://www.reactome.org/biopax/81/170941#Complex2197
# 734	437.31066846847534	http://www.reactome.org/biopax/81/170941#Complex2195
# 735	437.57653427124023	http://www.reactome.org/biopax/81/170941#Complex2198
# 736	437.8519902229309	http://www.reactome.org/biopax/81/170941#Complex2200
# 737	438.0849232673645	http://www.reactome.org/biopax/81/170941#Complex2202
# 738	438.3306577205658	http://www.reactome.org/biopax/81/170941#Complex2206
# 739	439.2850568294525	http://www.reactome.org/biopax/81/170941#Complex2208
# 740	440.06893944740295	http://www.reactome.org/biopax/81/170941#Complex2207
# 741	440.767071723938	http://www.reactome.org/biopax/81/170941#Complex2212
# 742	440.87191820144653	http://www.reactome.org/biopax/81/170941#Complex2214
# 743	441.0866177082062	http://www.reactome.org/biopax/81/170941#Complex2215
# 744	441.3369505405426	http://www.reactome.org/biopax/81/170941#Complex2216
# 745	441.62261939048767	http://www.reactome.org/biopax/81/170941#Complex2217
# 746	441.753075838089	http://www.reactome.org/biopax/81/170941#Complex2220
# 747	442.0992600917816	http://www.reactome.org/biopax/81/170941#Complex2223
# 748	442.4719572067261	http://www.reactome.org/biopax/81/170941#Complex2224
# 749	442.8115265369415	http://www.reactome.org/biopax/81/170941#Complex2225
# 750	443.7844281196594	http://www.reactome.org/biopax/81/170941#Complex2227
# 751	444.8298647403717	http://www.reactome.org/biopax/81/170941#Complex2228
# 752	445.7902684211731	http://www.reactome.org/biopax/81/170941#Complex2229
# 753	446.76815843582153	http://www.reactome.org/biopax/81/170941#Complex2231
# 754	447.5420506000519	http://www.reactome.org/biopax/81/170941#Complex2233
# 755	448.4904155731201	http://www.reactome.org/biopax/81/170941#Complex2234
# 756	449.40580201148987	http://www.reactome.org/biopax/81/170941#Complex2235
# 757	450.2136571407318	http://www.reactome.org/biopax/81/170941#Complex2236
# 758	450.9373595714569	http://www.reactome.org/biopax/81/170941#Complex2237
# 759	451.64231967926025	http://www.reactome.org/biopax/81/170941#Complex2238
# 760	452.4179537296295	http://www.reactome.org/biopax/81/170941#Complex2240
# 761	452.4807550907135	http://www.reactome.org/biopax/81/170941#Complex2248
# 762	452.57128953933716	http://www.reactome.org/biopax/81/170941#Complex2253
# 763	452.7056791782379	http://www.reactome.org/biopax/81/170941#Complex2254
# 764	452.80691719055176	http://www.reactome.org/biopax/81/170941#Complex2258
# 765	452.92359733581543	http://www.reactome.org/biopax/81/170941#Complex2261
# 766	452.98833441734314	http://www.reactome.org/biopax/81/170941#Complex2264
# 767	453.0549132823944	http://www.reactome.org/biopax/81/170941#Complex2266
# 768	453.1641080379486	http://www.reactome.org/biopax/81/170941#Complex2269
# 769	453.2409884929657	http://www.reactome.org/biopax/81/170941#Complex2275
# 770	453.29991340637207	http://www.reactome.org/biopax/81/170941#Complex2276
# 771	453.3618459701538	http://www.reactome.org/biopax/81/170941#Complex2280
# 772	453.4270112514496	http://www.reactome.org/biopax/81/170941#Complex2284
# 773	453.5385673046112	http://www.reactome.org/biopax/81/170941#Complex2293
# 774	454.27817726135254	http://www.reactome.org/biopax/81/170941#Complex2294
# 775	454.61947441101074	http://www.reactome.org/biopax/81/170941#Complex2299
# 776	454.71844363212585	http://www.reactome.org/biopax/81/170941#Complex2301
# 777	454.8601942062378	http://www.reactome.org/biopax/81/170941#Complex2305
# 778	454.9992473125458	http://www.reactome.org/biopax/81/170941#Complex2308
# 779	455.07780933380127	http://www.reactome.org/biopax/81/170941#Complex2306
# 780	455.1922872066498	http://www.reactome.org/biopax/81/170941#Complex2311
# 781	455.2992660999298	http://www.reactome.org/biopax/81/170941#Complex2314
# 782	455.4009883403778	http://www.reactome.org/biopax/81/170941#Complex2315
# 783	455.55213618278503	http://www.reactome.org/biopax/81/170941#Complex2316
# 784	455.67535495758057	http://www.reactome.org/biopax/81/170941#Complex2318
# 785	455.8298861980438	http://www.reactome.org/biopax/81/170941#Complex2322
# 786	455.91788935661316	http://www.reactome.org/biopax/81/170941#Complex2324
# 787	455.98931097984314	http://www.reactome.org/biopax/81/170941#Complex2326
# 788	456.1726803779602	http://www.reactome.org/biopax/81/170941#Complex2327
# 789	456.3311495780945	http://www.reactome.org/biopax/81/170941#Complex2329
# 790	456.42205333709717	http://www.reactome.org/biopax/81/170941#Complex2330
# 791	456.59444785118103	http://www.reactome.org/biopax/81/170941#Complex2332
# Duration: 456.7358047962189

# %%
# concat files
# %%bash
# ${JENA_HOME}/bat/riot --time --output=Turtle result/reactome-v79-Complex*.ttl > reactome-v79-complexes-invalid-fixed.ttl

# %%
# ${FUSEKI_HOME}\bat\riot.bat  --time --output=Turtle ./results/reactome-v81-48887-Complex*.ttl > ./results/reactome-v81-48887-complexes-invalid-fixed.ttl

# %%
startTime = time.time()
exportValidComplexes()
endTime = time.time()
print("Duration: {}".format(endTime - startTime))
# Out:
# Duration: 100.18700456619263

# %%
startTime = time.time()
deleteAllComplexes()
endTime = time.time()
print("Duration: {}".format(endTime - startTime))
# Out:
# Calling: http://localhost:3030/REACTOME_DDISCOIDEUM/update
# Duration: 81.42576360702515

# %% [markdown]
# ### (Merge files before identify and quantify redundant complexes after fixing)
